# %% [markdown]
# <a href="https://colab.research.google.com/github/r1zzzzzzza/-.-.--311/blob/main/%D0%BB%D0%B0%D0%B16_%D0%B2%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

celsius=[[-67.0],[-34.0],[0],[34.0],[54.0],[67.0],[100]]
farenheit=[[-88.6],[-29.2],[32.0],[93.2],[129.2],[152.6],[212.0]]

plt.figure(figsize=(15,8),dpi=50)
plt.scatter(celsius,farenheit,label='входные данные', color='green',marker='$f$')
plt.xlabel('celsius')
plt.ylabel('farenheit')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# цельсия[-67.0]=фаренгейт[-88.6]
# цельсия[-34.0]=фаренгейт[-29.2]
# цельсия[0]=фаренгейт[32.0]
# цельсия[34.0]=фаренгейт[93.2]
# цельсия[54.0]=фаренгейт[129.2]
# цельсия[67.0]=фаренгейт[152.6]
# цельсия[100]=фаренгейт[212.0]
# array([[-58. ],
#        [ 50. ],
#        [ 86. ],
#        [ 68. ],
#        [ 50. ],
#        [158. ],
#        [188.6]])

# %%
for c,f in zip(celsius,farenheit):
  print(f'цельсия{c}=фаренгейт{f}')

import sklearn.linear_model as lr
lr=LinearRegression()
lr.fit(celsius,farenheit)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
celsius_test=[[-50],[10],[30],[20],[10],[70],[87]]
farenheit_test=lr.predict(celsius_test)
farenheit_test
# Out:
# цельсия[-67.0]=фаренгейт[-88.6]
# цельсия[-34.0]=фаренгейт[-29.2]
# цельсия[0]=фаренгейт[32.0]
# цельсия[34.0]=фаренгейт[93.2]
# цельсия[54.0]=фаренгейт[129.2]
# цельсия[67.0]=фаренгейт[152.6]
# цельсия[100]=фаренгейт[212.0]
# array([[-58. ],
#        [ 50. ],
#        [ 86. ],
#        [ 68. ],
#        [ 50. ],
#        [158. ],
#        [188.6]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(celsius,farenheit)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
celsius_test=[[-50],[10],[30],[20],[10],[70],[87]]
farenheit_test=lr.predict(celsius_test)
farenheit_test
# Out:
# array([[-58. ],
#        [ 50. ],
#        [ 86. ],
#        [ 68. ],
#        [ 50. ],
#        [158. ],
#        [188.6]])

# %%
for c,f in zip(celsius_test,farenheit_test):
  print(f'цельсия{c},фаренгейта{f}')
# Out:
# цельсия[-50],фаренгейта[-58.]
# цельсия[10],фаренгейта[50.]
# цельсия[30],фаренгейта[86.]
# цельсия[20],фаренгейта[68.]
# цельсия[10],фаренгейта[50.]
# цельсия[70],фаренгейта[158.]
# цельсия[87],фаренгейта[188.6]

# %%
import numpy as np
x_range=np.arange(-70,120)
y_range=x_range*1.8+32

plt.figure(figsize=(15,8), dpi=280)
plt.plot(x_range, y_range, label='уравнение', linewidth='1')
plt.scatter(celsius, farenheit, label='входные данные', color='green', marker='$f$')
plt.scatter(celsius_test, farenheit_test, label='предсказанное значение', color='blue')
plt.xlabel('Цельсия')
plt.ylabel('Фаренгейта')
plt.legend()
plt.grid(True)
plt.show()

# %%
celsius=[[-67.0],[-34.0],[0],[34.0],[54.0],[67.0],[100]]
kalvin=[[206.0],[239.0],[273.0],[307.0],[327.0],[340.0],[373.0]]

plt.scatter(celsius,kalvin,label='входные данные', color='green',marker='$f$')
plt.xlabel('celsius')
plt.ylabel('kalvin')
plt.legend()
plt.grid(True)
plt.show()

for c,k in zip(celsius,kalvin):
  print(f'цельсия{c}=кельвин{f}')

import sklearn.linear_model as lr
lr=LinearRegression()
lr.fit(celsius,kalvin)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
celsius_test=[[-100],[100],[-200],[-273],[10],[70],[87]]
kalvin_test=lr.predict(celsius_test)
kalvin_test
# Out:
# цельсия[-67.0]=кельвин[212.0]
# цельсия[-34.0]=кельвин[212.0]
# цельсия[0]=кельвин[212.0]
# цельсия[34.0]=кельвин[212.0]
# цельсия[54.0]=кельвин[212.0]
# цельсия[67.0]=кельвин[212.0]
# цельсия[100]=кельвин[212.0]
# array([[ 1.73000000e+02],
#        [ 3.73000000e+02],
#        [ 7.30000000e+01],
#        [-1.13686838e-13],
#        [ 2.83000000e+02],
#        [ 3.43000000e+02],
#        [ 3.60000000e+02]])

# %%
for c,k in zip(celsius,kalvin):
  print(f'цельсия{c}=кельвин{f}')

import sklearn.linear_model as lr
lr=LinearRegression()
lr.fit(celsius,kalvin)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
celsius_test=[[-100],[100],[-200],[-273],[10],[70],[87]]
kalvin_test=lr.predict(celsius_test)
kalvin_test
# Out:
# цельсия[-67.0]=кельвин[212.0]
# цельсия[-34.0]=кельвин[212.0]
# цельсия[0]=кельвин[212.0]
# цельсия[34.0]=кельвин[212.0]
# цельсия[54.0]=кельвин[212.0]
# цельсия[67.0]=кельвин[212.0]
# цельсия[100]=кельвин[212.0]
# array([[ 1.73000000e+02],
#        [ 3.73000000e+02],
#        [ 7.30000000e+01],
#        [-1.13686838e-13],
#        [ 2.83000000e+02],
#        [ 3.43000000e+02],
#        [ 3.60000000e+02]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(celsius,kalvin)
lr.predict([[256],[123]])
lr.coef_
lr.intercept_
celsius_test=[[-50],[10],[30],[20],[10],[70],[87]]
kalvin_test=lr.predict(celsius_test)
kalvin_test
# Out:
# array([[223.],
#        [283.],
#        [303.],
#        [293.],
#        [283.],
#        [343.],
#        [360.]])

# %%
for c,f in zip(celsius_test,kalvin_test):
  print(f'цельсия{c},кельвина{f}')
# Out:
# цельсия[-50],кельвина[223.]
# цельсия[10],кельвина[283.]
# цельсия[30],кельвина[303.]
# цельсия[20],кельвина[293.]
# цельсия[10],кельвина[283.]
# цельсия[70],кельвина[343.]
# цельсия[87],кельвина[360.]

# %%
import numpy as np
k_range=np.arange(-70,120)
c_range=k_range+273

plt.figure(figsize=(15,8), dpi=280)
plt.plot(k_range, c_range, label='уравнение', linewidth='1')
plt.scatter(celsius, kalvin, label='входные данные', color='green', marker='$f$')
plt.scatter(celsius_test, kalvin_test, label='предсказанное значение', color='blue')
plt.xlabel('Цельсия')
plt.ylabel('Кельвина')
plt.legend()
plt.grid(True)
plt.show()

# %%
# !git clone https://github.com/r1zzzzzzza/-.-.--311
# Out:
# Cloning into '-.-.--311'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
from math import*
print(pi)
print(e)
print(nan)
print(factorial(1))
print(gcd(1), gcd(128))
# Out:
# 3.141592653589793
# 2.718281828459045
# nan
# 1
# 1 128
